# %% [markdown]
# <a href="https://colab.research.google.com/github/tobin21/python/blob/main/3_Index.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
data = {
    '이름': ['박보검', '신동엽', '박슬기', '김예원', '고은아', '한선화', '이해리', '강균성', '진운'],
    '대학교': ['명지대']*9,
    '전공': ['뮤지컬학과', '연극영화과', '영화뮤지컬학과', '영화뮤지컬학과', '연극영화과', '무용학과', '실용음악과', '실용음악과', '영화뮤지컬학과'],
    '졸업년도': ['2020', '1993', '2011', '2015', '2017', '2017', '2011', '졸업', '2013'],
    '글쓰기': [90, 95, 89, 86, 87, 91, 92, 90, 88],
    '영어': [85, 92, 84, 81, 88, 90, 89, 91, 85],
    '수학': [78, 85, 80, 77, 79, 82, 83, 86, 82],
    '통계': [82, 91, 83, 80, 86, 88, 90, 92, 87],
    '프로그래밍': ['Python', 'R', '', 'JavaScript', '', 'Python', '', 'Python', 'Java']
}
df = pd.DataFrame(data, index=['1번', '2번', '3번', '4번', '5번', '6번', '7번', '8번', '9번'])
df
# Out:
#      이름  대학교       전공  졸업년도  글쓰기  영어  수학  통계       프로그래밍
# 1번  박보검  명지대    뮤지컬학과  2020   90  85  78  82      Python
# 2번  신동엽  명지대    연극영화과  1993   95  92  85  91           R
# 3번  박슬기  명지대  영화뮤지컬학과  2011   89  84  80  83
# 4번  김예원  명지대  영화뮤지컬학과  2015   86  81  77  80  JavaScript
# 5번  고은아  명지대    연극영화과  2017   87  88  79  86
# 6번  한선화  명지대     무용학과  2017   91  90  82  88      Python
# 7번  이해리  명지대    실용음악과  2011   92  89  83  90
# 8번  강균성  명지대    실용음악과    졸업   90  91  86  92      Python
# 9번   진운  명지대  영화뮤지컬학과  2013   88  85  82  87        Java
